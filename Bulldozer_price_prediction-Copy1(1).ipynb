# %% [markdown]
# # Sale Price prediction for bulldozers

# %% [markdown]
# ### In this notebook I am  going to predict a sale price of bulldozers in the function of time and using given features.

# %% [markdown]
# ### Problem definition:
# *How good I'll be able to train a model that predict sale price of bulldozers using data and features downloaded from Kaggle.*

# %% [markdown]
# ### Data:
# Downloaded from:
#
# Train and valid sets:
#
# *https://www.kaggle.com/competitions/bluebook-for-bulldozers/data?select=TrainAndValid.csv*
#
#
# *Train.csv is the training set, which contains data through the end of 2011.*
#
# *Valid.csv is the validation set, which contains data from January 1, 2012 - April 30, 2012 You make predictions on this set throughout the majority of the competition. Your score on this set is used to create the public leaderboard.*

# %% [markdown]
# ### Features:
# Downloaded from:
# *https://www.kaggle.com/competitions/bluebook-for-bulldozers/data?select=Data+Dictionary.xlsx*
#
# ### Evaluation:
# The evaluation metric for this competition is the RMSLE (root mean squared log error) between the actual and predicted auction prices.
#
# #### *note:  my goal is to minimize RMSLE.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import datetime as dt
# %matplotlib inline

# %%
# Loading the train_valid file.
train_valid = pd.read_csv('f:/TrainAndValid.csv',low_memory=False)

# %%
# Gerneral view of data structure.
train_valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
#  13  fiModelSeries             58667 non-null   object
#  14  fiModelDescriptor         74816 non-null   object
#  15  ProductSize               196093 non-null  object
#  16  fiProductClassDesc        412698 non-null  object
#  17  state                     412698 non-null  object
#  18  ProductGroup              412698 non-null  object
#  19  ProductGroupDesc          412698 non-null  object
#  20  Drive_System              107087 non-null  object
#  21  Enclosure                 412364 non-null  object
#  22  Forks                     197715 non-null  object
#  23  Pad_Type                  81096 non-null   object
#  24  Ride_Control              152728 non-null  object
#  25  Stick                     81096 non-null   object
#  26  Transmission              188007 non-null  object
#  27  Turbocharged              81096 non-null   object
#  28  Blade_Extension           25983 non-null   object
#  29  Blade_Width               25983 non-null   object
#  30  Enclosure_Type            25983 non-null   object
#  31  Engine_Horsepower         25983 non-null   object
#  32  Hydraulics                330133 non-null  object
#  33  Pushblock                 25983 non-null   object
#  34  Ripper                    106945 non-null  object
#  35  Scarifier                 25994 non-null   object
#  36  Tip_Control               25983 non-null   object
#  37  Tire_Size                 97638 non-null   object
#  38  Coupler                   220679 non-null  object
#  39  Coupler_System            44974 non-null   object
#  40  Grouser_Tracks            44875 non-null   object
#  41  Hydraulics_Flow           44875 non-null   object
#  42  Track_Type                102193 non-null  object
#  43  Undercarriage_Pad_Width   102916 non-null  object
#  44  Stick_Length              102261 non-null  object
#  45  Thumb                     102332 non-null  object
#  46  Pattern_Changer           102261 non-null  object
#  47  Grouser_Type              102193 non-null  object
#  48  Backhoe_Mounting          80712 non-null   object
#  49  Blade_Type                81875 non-null   object
#  50  Travel_Controls           81877 non-null   object
#  51  Differential_Type         71564 non-null   object
#  52  Steering_Controls         71522 non-null   object
# dtypes: float64(3), int64(5), object(45)
# memory usage: 166.9+ MB

# %%
# General view on missing labels quantity.
train_valid.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# Turbocharged                331602
# Blade_Extension             386715
# Blade_Width                 386715
# Enclosure_Type              386715
# Engine_Horsepower           386715
# Hydraulics                   82565
# Pushblock                   386715
# Ripper                      305753
# Scarifier                   386704
# Tip_Control                 386715
# Tire_Size                   315060
# Coupler                     192019
# Coupler_System              367724
# Grouser_Tracks              367823
# Hydraulics_Flow             367823
# Track_Type                  310505
# Undercarriage_Pad_Width     309782
# Stick_Length                310437
# Thumb                       310366
# Pattern_Changer             310437
# Grouser_Type                310505
# Backhoe_Mounting            331986
# Blade_Type                  330823
# Travel_Controls             330821
# Differential_Type           341134
# Steering_Controls           341176
# dtype: int64

# %% [markdown]
# ### Because we deal with time series data it is recommended  to parse the dates, so we have to import the data once again with parse dates parameter for chosen column.

# %%
# Import train_valid set with parse_dates parameter.
train_valid = pd.read_csv('f:/TrainAndValid.csv',low_memory=False,parse_dates=['saledate'])

# %% [markdown]
# ###      We are going to copy of the original datasets so all of the changes would not affect oryginal datasets.

# %%
train_valid_copy = train_valid.copy()

# %% [markdown]
# ### Sorting data by 'saledate' to have a better view af sales in a function of time.

# %%
train_valid_copy.sort_values(by=['saledate'],inplace=True)

# %%
train_valid_copy.saledate
# Out:
# 205615   1989-01-17
# 274835   1989-01-31
# 141296   1989-01-31
# 212552   1989-01-31
# 62755    1989-01-31
#             ...
# 410879   2012-04-28
# 412476   2012-04-28
# 411927   2012-04-28
# 407124   2012-04-28
# 409203   2012-04-28
# Name: saledate, Length: 412698, dtype: datetime64[ns]

# %% [markdown]
# ### Check of actual data structure and types.

# %%
train_valid_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 205615 to 409203
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  datetime64[ns]
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
#  13  fiModelSeries             58667 non-null   object
#  14  fiModelDescriptor         74816 non-null   object
#  15  ProductSize               196093 non-null  object
#  16  fiProductClassDesc        412698 non-null  object
#  17  state                     412698 non-null  object
#  18  ProductGroup              412698 non-null  object
#  19  ProductGroupDesc          412698 non-null  object
#  20  Drive_System              107087 non-null  object
#  21  Enclosure                 412364 non-null  object
#  22  Forks                     197715 non-null  object
#  23  Pad_Type                  81096 non-null   object
#  24  Ride_Control              152728 non-null  object
#  25  Stick                     81096 non-null   object
#  26  Transmission              188007 non-null  object
#  27  Turbocharged              81096 non-null   object
#  28  Blade_Extension           25983 non-null   object
#  29  Blade_Width               25983 non-null   object
#  30  Enclosure_Type            25983 non-null   object
#  31  Engine_Horsepower         25983 non-null   object
#  32  Hydraulics                330133 non-null  object
#  33  Pushblock                 25983 non-null   object
#  34  Ripper                    106945 non-null  object
#  35  Scarifier                 25994 non-null   object
#  36  Tip_Control               25983 non-null   object
#  37  Tire_Size                 97638 non-null   object
#  38  Coupler                   220679 non-null  object
#  39  Coupler_System            44974 non-null   object
#  40  Grouser_Tracks            44875 non-null   object
#  41  Hydraulics_Flow           44875 non-null   object
#  42  Track_Type                102193 non-null  object
#  43  Undercarriage_Pad_Width   102916 non-null  object
#  44  Stick_Length              102261 non-null  object
#  45  Thumb                     102332 non-null  object
#  46  Pattern_Changer           102261 non-null  object
#  47  Grouser_Type              102193 non-null  object
#  48  Backhoe_Mounting          80712 non-null   object
#  49  Blade_Type                81875 non-null   object
#  50  Travel_Controls           81877 non-null   object
#  51  Differential_Type         71564 non-null   object
#  52  Steering_Controls         71522 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(44)
# memory usage: 170.0+ MB

# %%
train_valid_copy.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# Turbocharged                331602
# Blade_Extension             386715
# Blade_Width                 386715
# Enclosure_Type              386715
# Engine_Horsepower           386715
# Hydraulics                   82565
# Pushblock                   386715
# Ripper                      305753
# Scarifier                   386704
# Tip_Control                 386715
# Tire_Size                   315060
# Coupler                     192019
# Coupler_System              367724
# Grouser_Tracks              367823
# Hydraulics_Flow             367823
# Track_Type                  310505
# Undercarriage_Pad_Width     309782
# Stick_Length                310437
# Thumb                       310366
# Pattern_Changer             310437
# Grouser_Type                310505
# Backhoe_Mounting            331986
# Blade_Type                  330823
# Travel_Controls             330821
# Differential_Type           341134
# Steering_Controls           341176
# dtype: int64

# %% [markdown]
# ### As we see we have mostly 'Object' type of data and a few numeric type.We can also see there is a big quantity of missing data.
# ### To start modelling we must change 'Object' type data into numbers ,as well as get sorted missing values.

# %% [markdown]
# ### One of ways to change 'object' / 'string' type data into numbers is to make them categorical type.

# %%
# Changing 'Object' type columns into category type.
for label,col in train_valid_copy.items():
    if pd.api.types.is_object_dtype(col):
        train_valid_copy[label] = col.astype('category')

# %%
train_valid_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 205615 to 409203
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   saledate                  412698 non-null  datetime64[ns]
#  10  fiModelDesc               412698 non-null  category
#  11  fiBaseModel               412698 non-null  category
#  12  fiSecondaryDesc           271971 non-null  category
#  13  fiModelSeries             58667 non-null   category
#  14  fiModelDescriptor         74816 non-null   category
#  15  ProductSize               196093 non-null  category
#  16  fiProductClassDesc        412698 non-null  category
#  17  state                     412698 non-null  category
#  18  ProductGroup              412698 non-null  category
#  19  ProductGroupDesc          412698 non-null  category
#  20  Drive_System              107087 non-null  category
#  21  Enclosure                 412364 non-null  category
#  22  Forks                     197715 non-null  category
#  23  Pad_Type                  81096 non-null   category
#  24  Ride_Control              152728 non-null  category
#  25  Stick                     81096 non-null   category
#  26  Transmission              188007 non-null  category
#  27  Turbocharged              81096 non-null   category
#  28  Blade_Extension           25983 non-null   category
#  29  Blade_Width               25983 non-null   category
#  30  Enclosure_Type            25983 non-null   category
#  31  Engine_Horsepower         25983 non-null   category
#  32  Hydraulics                330133 non-null  category
#  33  Pushblock                 25983 non-null   category
#  34  Ripper                    106945 non-null  category
#  35  Scarifier                 25994 non-null   category
#  36  Tip_Control               25983 non-null   category
#  37  Tire_Size                 97638 non-null   category
#  38  Coupler                   220679 non-null  category
#  39  Coupler_System            44974 non-null   category
#  40  Grouser_Tracks            44875 non-null   category
#  41  Hydraulics_Flow           44875 non-null   category
#  42  Track_Type                102193 non-null  category
#  43  Undercarriage_Pad_Width   102916 non-null  category
#  44  Stick_Length              102261 non-null  category
#  45  Thumb                     102332 non-null  category
#  46  Pattern_Changer           102261 non-null  category
#  47  Grouser_Type              102193 non-null  category
#  48  Backhoe_Mounting          80712 non-null   category
#  49  Blade_Type                81875 non-null   category
#  50  Travel_Controls           81877 non-null   category
#  51  Differential_Type         71564 non-null   category
#  52  Steering_Controls         71522 non-null   category
# dtypes: category(44), datetime64[ns](1), float64(3), int64(5)
# memory usage: 50.6 MB

# %%
# Sorting data by "saledate" columns.
train_valid_copy.sort_values(by='saledate',inplace=True)

# %%
# Filling missing data for numeric type with median of numeric columns.
for label,col in train_valid_copy.items():
    if pd.api.types.is_numeric_dtype(col):
        if pd.isnull(col).sum():
            train_valid_copy[label] = col.fillna(col.median())

# %%
# Changing categorical type to numeric values:
for label,col in train_valid_copy.items():
    if label == 'saledate':
        continue
    if not pd.api.types.is_numeric_dtype(col):
        train_valid_copy[label] = pd.Categorical(col).codes + 1

# %%
train_valid_copy.isnull().sum()
# Out:
# SalesID                     0
# SalePrice                   0
# MachineID                   0
# ModelID                     0
# datasource                  0
# auctioneerID                0
# YearMade                    0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# saledate                    0
# fiModelDesc                 0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# fiModelDescriptor           0
# ProductSize                 0
# fiProductClassDesc          0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# dtype: int64

# %%
train_valid_copy.dtypes
# Out:
# SalesID                              int64
# SalePrice                          float64
# MachineID                            int64
# ModelID                              int64
# datasource                           int64
# auctioneerID                       float64
# YearMade                             int64
# MachineHoursCurrentMeter           float64
# UsageBand                             int8
# saledate                    datetime64[ns]
# fiModelDesc                          int16
# fiBaseModel                          int16
# fiSecondaryDesc                      int16
# fiModelSeries                         int8
# fiModelDescriptor                    int16
# ProductSize                           int8
# fiProductClassDesc                    int8
# state                                 int8
# ProductGroup                          int8
# ProductGroupDesc                      int8
# Drive_System                          int8
# Enclosure                             int8
# Forks                                 int8
# Pad_Type                              int8
# Ride_Control                          int8
# Stick                                 int8
# Transmission                          int8
# Turbocharged                          int8
# Blade_Extension                       int8
# Blade_Width                           int8
# Enclosure_Type                        int8
# Engine_Horsepower                     int8
# Hydraulics                            int8
# Pushblock                             int8
# Ripper                                int8
# Scarifier                             int8
# Tip_Control                           int8
# Tire_Size                             int8
# Coupler                               int8
# Coupler_System                        int8
# Grouser_Tracks                        int8
# Hydraulics_Flow                       int8
# Track_Type                            int8
# Undercarriage_Pad_Width               int8
# Stick_Length                          int8
# Thumb                                 int8
# Pattern_Changer                       int8
# Grouser_Type                          int8
# Backhoe_Mounting                      int8
# Blade_Type                            int8
# Travel_Controls                       int8
# Differential_Type                     int8
# Steering_Controls                     int8
# dtype: object

# %% [markdown]
# ## Now when we have only numerical values in our dataset,we are able to split set into train and valid sets separately as documentation says.

# %% [markdown]
# #### Train.csv is the training set, which contains data through the end of 2011.
# #### Valid.csv is the validation set, which contains data from January 1, 2012 - April 30, 2012.
#
# You make predictions on this set throughout the majority of the competition. Your score on this set is used to create the public leaderboard.

# %% [markdown]
# ##### As it's written the split is dependent to the date,telling that untill the end of 2011 data should be in Train.csv
# ##### and Valid.csv should be from 1.1.2012 - 30.04.2012.
# ##### By using our 'saledate' column we are able to split our train_valid.copy dataframe into train and test sets.

# %%
train_valid_copy.T
# Out:
#                                        205615               233186  \
# SalesID                               1646770              1728883
# SalePrice                              9500.0              30000.0
# MachineID                             1126363              1523610
# ModelID                                  8434                 9105
# datasource                                132                  132
# auctioneerID                             18.0                 99.0
# YearMade                                 1974                 1986
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  1989-01-17 00:00:00  1989-01-31 00:00:00
# fiModelDesc                              4593                 4772
# fiBaseModel                              1744                 1852
# fiSecondaryDesc                             0                    0
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 4                    0
# fiProductClassDesc                         47                   73
# state                                      44                    9
# ProductGroup                                5                    6
# ProductGroupDesc                            5                    6
# Drive_System                                0                    0
# Enclosure                                   6                    1
# Forks                                       0                    0
# Pad_Type                                    0                    0
# Ride_Control                                0                    0
# Stick                                       0                    0
# Transmission                                3                    0
# Turbocharged                                0                    0
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  1                    0
# Pushblock                                   0                    0
# Ripper                                      2                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                   14
# Coupler                                     0                    0
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  0                    0
# Undercarriage_Pad_Width                     0                    0
# Stick_Length                                0                    0
# Thumb                                       0                    0
# Pattern_Changer                             0                    0
# Grouser_Type                                0                    0
# Backhoe_Mounting                            1                    0
# Blade_Type                                  8                    0
# Travel_Controls                             6                    0
# Differential_Type                           0                    0
# Steering_Controls                           0                    0
#
#                                        142491               115536  \
# SalesID                               1508502              1452578
# SalePrice                             21000.0              33000.0
# MachineID                             1153157              1544443
# ModelID                                  4138                 3854
# datasource                                132                  132
# auctioneerID                             99.0                 99.0
# YearMade                                 1972                 1974
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  1989-01-31 00:00:00  1989-01-31 00:00:00
# fiModelDesc                              2347                 1767
# fiBaseModel                               713                  535
# fiSecondaryDesc                            57                   31
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 2                    4
# fiProductClassDesc                         50                   62
# state                                       9                    9
# ProductGroup                                5                    6
# ProductGroupDesc                            5                    6
# Drive_System                                0                    0
# Enclosure                                   6                    1
# Forks                                       0                    1
# Pad_Type                                    0                    0
# Ride_Control                                0                    2
# Stick                                       0                    0
# Transmission                                8                    0
# Turbocharged                                0                    0
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  1                    1
# Pushblock                                   0                    0
# Ripper                                      2                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                   12
# Coupler                                     0                    3
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  0                    0
# Undercarriage_Pad_Width                     0                    0
# Stick_Length                                0                    0
# Thumb                                       0                    0
# Pattern_Changer                             0                    0
# Grouser_Type                                0                    0
# Backhoe_Mounting                            1                    0
# Blade_Type                                  1                    0
# Travel_Controls                             6                    0
# Differential_Type                           0                    4
# Steering_Controls                           0                    2
#
#                                        92301                115892  \
# SalesID                               1403418              1453054
# SalePrice                             24000.0              36000.0
# MachineID                             1390168              1117184
# ModelID                                  7110                 3854
# datasource                                132                  132
# auctioneerID                             99.0                 99.0
# YearMade                                 1986                 1977
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  1989-01-31 00:00:00  1989-01-31 00:00:00
# fiModelDesc                               744                 1767
# fiBaseModel                               245                  535
# fiSecondaryDesc                             0                   31
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 0                    4
# fiProductClassDesc                          2                   62
# state                                       9                    9
# ProductGroup                                1                    6
# ProductGroupDesc                            1                    6
# Drive_System                                4                    0
# Enclosure                                   1                    1
# Forks                                       1                    1
# Pad_Type                                    2                    0
# Ride_Control                                1                    2
# Stick                                       1                    0
# Transmission                                8                    0
# Turbocharged                                1                    0
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  0                    1
# Pushblock                                   0                    0
# Ripper                                      0                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                   12
# Coupler                                     0                    3
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  0                    0
# Undercarriage_Pad_Width                     0                    0
# Stick_Length                                0                    0
# Thumb                                       0                    0
# Pattern_Changer                             0                    0
# Grouser_Type                                0                    0
# Backhoe_Mounting                            0                    0
# Blade_Type                                  0                    0
# Travel_Controls                             0                    0
# Differential_Type                           0                    4
# Steering_Controls                           0                    2
#
#                                        134080               92294   \
# SalesID                               1491298              1403411
# SalePrice                             46000.0              23000.0
# MachineID                             1322436              1184544
# ModelID                                  4107                 7110
# datasource                                132                  132
# auctioneerID                             99.0                 99.0
# YearMade                                 1987                 1986
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  1989-01-31 00:00:00  1989-01-31 00:00:00
# fiModelDesc                              2178                  744
# fiBaseModel                               692                  245
# fiSecondaryDesc                            61                    0
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 0                    0
# fiProductClassDesc                         54                    2
# state                                       9                    9
# ProductGroup                                5                    1
# ProductGroupDesc                            5                    1
# Drive_System                                0                    4
# Enclosure                                   6                    1
# Forks                                       0                    1
# Pad_Type                                    0                    2
# Ride_Control                                0                    1
# Stick                                       0                    2
# Transmission                                8                    8
# Turbocharged                                0                    1
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  1                    0
# Pushblock                                   0                    0
# Ripper                                      2                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                    0
# Coupler                                     0                    0
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  0                    0
# Undercarriage_Pad_Width                     0                    0
# Stick_Length                                0                    0
# Thumb                                       0                    0
# Pattern_Changer                             0                    0
# Grouser_Type                                0                    0
# Backhoe_Mounting                            1                    0
# Blade_Type                                  6                    0
# Travel_Controls                             6                    0
# Differential_Type                           0                    0
# Steering_Controls                           0                    0
#
#                                        31494                140922  ...  \
# SalesID                               1263797              1504404  ...
# SalePrice                             17000.0              26000.0  ...
# MachineID                             1526902              1310407  ...
# ModelID                                  6953                 4139  ...
# datasource                                132                  132  ...
# auctioneerID                             99.0                 99.0  ...
# YearMade                                 1983                 1975  ...
# MachineHoursCurrentMeter                  0.0                  0.0  ...
# UsageBand                                   0                    0  ...
# saledate                  1989-01-31 00:00:00  1989-01-31 00:00:00  ...
# fiModelDesc                              4741                 2348  ...
# fiBaseModel                              1837                  713  ...
# fiSecondaryDesc                             0                   59  ...
# fiModelSeries                               0                    0  ...
# fiModelDescriptor                           0                    0  ...
# ProductSize                                 0                    2  ...
# fiProductClassDesc                         57                   50  ...
# state                                       9                    9  ...
# ProductGroup                                6                    5  ...
# ProductGroupDesc                            6                    5  ...
# Drive_System                                0                    0  ...
# Enclosure                                   6                    6  ...
# Forks                                       1                    0  ...
# Pad_Type                                    0                    0  ...
# Ride_Control                                2                    0  ...
# Stick                                       0                    0  ...
# Transmission                                0                    8  ...
# Turbocharged                                0                    0  ...
# Blade_Extension                             0                    0  ...
# Blade_Width                                 0                    0  ...
# Enclosure_Type                              0                    0  ...
# Engine_Horsepower                           0                    0  ...
# Hydraulics                                  1                    1  ...
# Pushblock                                   0                    0  ...
# Ripper                                      0                    2  ...
# Scarifier                                   0                    0  ...
# Tip_Control                                 0                    0  ...
# Tire_Size                                  17                    0  ...
# Coupler                                     3                    0  ...
# Coupler_System                              0                    0  ...
# Grouser_Tracks                              0                    0  ...
# Hydraulics_Flow                             0                    0  ...
# Track_Type                                  0                    0  ...
# Undercarriage_Pad_Width                     0                    0  ...
# Stick_Length                                0                    0  ...
# Thumb                                       0                    0  ...
# Pattern_Changer                             0                    0  ...
# Grouser_Type                                0                    0  ...
# Backhoe_Mounting                            0                    1  ...
# Blade_Type                                  0                    1  ...
# Travel_Controls                             0                    6  ...
# Differential_Type                           4                    0  ...
# Steering_Controls                           2                    0  ...
#
#                                        407382               405913  \
# SalesID                               6267915              6257872
# SalePrice                             47000.0              13000.0
# MachineID                             1844076              1837259
# ModelID                                  3362                 3218
# datasource                                149                  149
# auctioneerID                             99.0                 99.0
# YearMade                                 1977                 1995
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  2012-04-28 00:00:00  2012-04-28 00:00:00
# fiModelDesc                               107                 1330
# fiBaseModel                                30                  383
# fiSecondaryDesc                            59                   21
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 0                    4
# fiProductClassDesc                         32                   61
# state                                       5                    5
# ProductGroup                                2                    6
# ProductGroupDesc                            2                    6
# Drive_System                                3                    0
# Enclosure                                   3                    1
# Forks                                       0                    1
# Pad_Type                                    0                    0
# Ride_Control                                0                    2
# Stick                                       0                    0
# Transmission                                5                    0
# Turbocharged                                0                    0
# Blade_Extension                             1                    0
# Blade_Width                                 3                    0
# Enclosure_Type                              3                    0
# Engine_Horsepower                           1                    0
# Hydraulics                                  5                    1
# Pushblock                                   2                    0
# Ripper                                      4                    0
# Scarifier                                   1                    0
# Tip_Control                                 1                    0
# Tire_Size                                  17                   17
# Coupler                                     0                    3
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  0                    0
# Undercarriage_Pad_Width                     0                    0
# Stick_Length                                0                    0
# Thumb                                       0                    0
# Pattern_Changer                             0                    0
# Grouser_Type                                0                    0
# Backhoe_Mounting                            0                    0
# Blade_Type                                  0                    0
# Travel_Controls                             0                    0
# Differential_Type                           0                    4
# Steering_Controls                           0                    2
#
#                                        405915               411423  \
# SalesID                               6257884              6309986
# SalePrice                             16500.0              16000.0
# MachineID                             1897564              1899882
# ModelID                                  3263                 9508
# datasource                                149                  149
# auctioneerID                             99.0                 99.0
# YearMade                                 1996                 2005
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  2012-04-28 00:00:00  2012-04-28 00:00:00
# fiModelDesc                              1706                  613
# fiBaseModel                               515                  198
# fiSecondaryDesc                            21                    0
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 4                    5
# fiProductClassDesc                         65                   17
# state                                       5                    5
# ProductGroup                                6                    4
# ProductGroupDesc                            6                    4
# Drive_System                                0                    0
# Enclosure                                   1                    1
# Forks                                       1                    0
# Pad_Type                                    0                    0
# Ride_Control                                2                    0
# Stick                                       0                    0
# Transmission                                0                    0
# Turbocharged                                0                    0
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  1                    4
# Pushblock                                   0                    0
# Ripper                                      0                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                  17                    0
# Coupler                                     3                    3
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  0                    2
# Undercarriage_Pad_Width                     0                   19
# Stick_Length                                0                   29
# Thumb                                       0                    3
# Pattern_Changer                             0                    2
# Grouser_Type                                0                    1
# Backhoe_Mounting                            0                    0
# Blade_Type                                  0                    0
# Travel_Controls                             0                    0
# Differential_Type                           4                    0
# Steering_Controls                           2                    0
#
#                                        412544               409901  \
# SalesID                               6327732              6286556
# SalePrice                             11000.0              23000.0
# MachineID                             1906978              1793587
# ModelID                                 12524                 4605
# datasource                                149                  149
# auctioneerID                             99.0                 99.0
# YearMade                                 2006                 2006
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  2012-04-28 00:00:00  2012-04-28 00:00:00
# fiModelDesc                              4550                  500
# fiBaseModel                              1713                  176
# fiSecondaryDesc                             0                   59
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 5                    0
# fiProductClassDesc                         17                    2
# state                                       5                    5
# ProductGroup                                4                    1
# ProductGroupDesc                            4                    1
# Drive_System                                0                    2
# Enclosure                                   1                    6
# Forks                                       0                    1
# Pad_Type                                    0                    2
# Ride_Control                                0                    1
# Stick                                       0                    1
# Transmission                                0                    8
# Turbocharged                                0                    1
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  4                    0
# Pushblock                                   0                    0
# Ripper                                      0                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                    0
# Coupler                                     2                    0
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  1                    0
# Undercarriage_Pad_Width                    19                    0
# Stick_Length                               29                    0
# Thumb                                       3                    0
# Pattern_Changer                             2                    0
# Grouser_Type                                1                    0
# Backhoe_Mounting                            0                    0
# Blade_Type                                  0                    0
# Travel_Controls                             0                    0
# Differential_Type                           0                    0
# Steering_Controls                           0                    0
#
#                                        405777               411889  \
# SalesID                               6256957              6312472
# SalePrice                             11500.0              11000.0
# MachineID                             1860454              1820676
# ModelID                                  6868                17231
# datasource                                149                  149
# auctioneerID                             99.0                 99.0
# YearMade                                 1000                 2006
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  2012-04-28 00:00:00  2012-04-28 00:00:00
# fiModelDesc                              1679                  581
# fiBaseModel                               505                  191
# fiSecondaryDesc                             0                    0
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 3                    5
# fiProductClassDesc                         19                    6
# state                                       5                    5
# ProductGroup                                4                    4
# ProductGroupDesc                            4                    4
# Drive_System                                0                    0
# Enclosure                                   1                    1
# Forks                                       0                    0
# Pad_Type                                    0                    0
# Ride_Control                                0                    0
# Stick                                       0                    0
# Transmission                                0                    0
# Turbocharged                                0                    0
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                 12                    4
# Pushblock                                   0                    0
# Ripper                                      0                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                    0
# Coupler                                     3                    3
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  2                    2
# Undercarriage_Pad_Width                    19                   19
# Stick_Length                               29                   29
# Thumb                                       2                    3
# Pattern_Changer                             2                    2
# Grouser_Type                                1                    1
# Backhoe_Mounting                            0                    0
# Blade_Type                                  0                    0
# Travel_Controls                             0                    0
# Differential_Type                           0                    0
# Steering_Controls                           0                    0
#
#                                        411890               409203
# SalesID                               6312473              6283635
# SalePrice                             11000.0              34000.0
# MachineID                             1796787              1869284
# ModelID                                 17231                 4701
# datasource                                149                  149
# auctioneerID                             99.0                 99.0
# YearMade                                 2006                 1000
# MachineHoursCurrentMeter                  0.0                  0.0
# UsageBand                                   0                    0
# saledate                  2012-04-28 00:00:00  2012-04-28 00:00:00
# fiModelDesc                               581                  989
# fiBaseModel                               191                  307
# fiSecondaryDesc                             0                   61
# fiModelSeries                               0                    0
# fiModelDescriptor                           0                    0
# ProductSize                                 5                    0
# fiProductClassDesc                          6                   60
# state                                       5                    5
# ProductGroup                                4                    6
# ProductGroupDesc                            4                    6
# Drive_System                                0                    0
# Enclosure                                   1                    3
# Forks                                       0                    1
# Pad_Type                                    0                    0
# Ride_Control                                0                    2
# Stick                                       0                    0
# Transmission                                0                    0
# Turbocharged                                0                    0
# Blade_Extension                             0                    0
# Blade_Width                                 0                    0
# Enclosure_Type                              0                    0
# Engine_Horsepower                           0                    0
# Hydraulics                                  4                    1
# Pushblock                                   0                    0
# Ripper                                      0                    0
# Scarifier                                   0                    0
# Tip_Control                                 0                    0
# Tire_Size                                   0                    9
# Coupler                                     3                    3
# Coupler_System                              0                    0
# Grouser_Tracks                              0                    0
# Hydraulics_Flow                             0                    0
# Track_Type                                  2                    0
# Undercarriage_Pad_Width                    19                    0
# Stick_Length                               29                    0
# Thumb                                       3                    0
# Pattern_Changer                             2                    0
# Grouser_Type                                1                    0
# Backhoe_Mounting                            0                    0
# Blade_Type                                  0                    0
# Travel_Controls                             0                    0
# Differential_Type                           0                    4
# Steering_Controls                           0                    2
#
# [53 rows x 412698 columns]

# %%
train_valid_copy['YearOfSale'] = train_valid_copy['saledate'].dt.year
train_valid_copy.drop(['saledate'],axis=1,inplace=True)

# %%
train_valid_copy.head().T
# Out:
#                              205615     233186     142491     115536  \
# SalesID                   1646770.0  1728883.0  1508502.0  1452578.0
# SalePrice                    9500.0    30000.0    21000.0    33000.0
# MachineID                 1126363.0  1523610.0  1153157.0  1544443.0
# ModelID                      8434.0     9105.0     4138.0     3854.0
# datasource                    132.0      132.0      132.0      132.0
# auctioneerID                   18.0       99.0       99.0       99.0
# YearMade                     1974.0     1986.0     1972.0     1974.0
# MachineHoursCurrentMeter        0.0        0.0        0.0        0.0
# UsageBand                       0.0        0.0        0.0        0.0
# fiModelDesc                  4593.0     4772.0     2347.0     1767.0
# fiBaseModel                  1744.0     1852.0      713.0      535.0
# fiSecondaryDesc                 0.0        0.0       57.0       31.0
# fiModelSeries                   0.0        0.0        0.0        0.0
# fiModelDescriptor               0.0        0.0        0.0        0.0
# ProductSize                     4.0        0.0        2.0        4.0
# fiProductClassDesc             47.0       73.0       50.0       62.0
# state                          44.0        9.0        9.0        9.0
# ProductGroup                    5.0        6.0        5.0        6.0
# ProductGroupDesc                5.0        6.0        5.0        6.0
# Drive_System                    0.0        0.0        0.0        0.0
# Enclosure                       6.0        1.0        6.0        1.0
# Forks                           0.0        0.0        0.0        1.0
# Pad_Type                        0.0        0.0        0.0        0.0
# Ride_Control                    0.0        0.0        0.0        2.0
# Stick                           0.0        0.0        0.0        0.0
# Transmission                    3.0        0.0        8.0        0.0
# Turbocharged                    0.0        0.0        0.0        0.0
# Blade_Extension                 0.0        0.0        0.0        0.0
# Blade_Width                     0.0        0.0        0.0        0.0
# Enclosure_Type                  0.0        0.0        0.0        0.0
# Engine_Horsepower               0.0        0.0        0.0        0.0
# Hydraulics                      1.0        0.0        1.0        1.0
# Pushblock                       0.0        0.0        0.0        0.0
# Ripper                          2.0        0.0        2.0        0.0
# Scarifier                       0.0        0.0        0.0        0.0
# Tip_Control                     0.0        0.0        0.0        0.0
# Tire_Size                       0.0       14.0        0.0       12.0
# Coupler                         0.0        0.0        0.0        3.0
# Coupler_System                  0.0        0.0        0.0        0.0
# Grouser_Tracks                  0.0        0.0        0.0        0.0
# Hydraulics_Flow                 0.0        0.0        0.0        0.0
# Track_Type                      0.0        0.0        0.0        0.0
# Undercarriage_Pad_Width         0.0        0.0        0.0        0.0
# Stick_Length                    0.0        0.0        0.0        0.0
# Thumb                           0.0        0.0        0.0        0.0
# Pattern_Changer                 0.0        0.0        0.0        0.0
# Grouser_Type                    0.0        0.0        0.0        0.0
# Backhoe_Mounting                1.0        0.0        1.0        0.0
# Blade_Type                      8.0        0.0        1.0        0.0
# Travel_Controls                 6.0        0.0        6.0        0.0
# Differential_Type               0.0        0.0        0.0        4.0
# Steering_Controls               0.0        0.0        0.0        2.0
# YearOfSale                   1989.0     1989.0     1989.0     1989.0
#
#                              92301
# SalesID                   1403418.0
# SalePrice                   24000.0
# MachineID                 1390168.0
# ModelID                      7110.0
# datasource                    132.0
# auctioneerID                   99.0
# YearMade                     1986.0
# MachineHoursCurrentMeter        0.0
# UsageBand                       0.0
# fiModelDesc                   744.0
# fiBaseModel                   245.0
# fiSecondaryDesc                 0.0
# fiModelSeries                   0.0
# fiModelDescriptor               0.0
# ProductSize                     0.0
# fiProductClassDesc              2.0
# state                           9.0
# ProductGroup                    1.0
# ProductGroupDesc                1.0
# Drive_System                    4.0
# Enclosure                       1.0
# Forks                           1.0
# Pad_Type                        2.0
# Ride_Control                    1.0
# Stick                           1.0
# Transmission                    8.0
# Turbocharged                    1.0
# Blade_Extension                 0.0
# Blade_Width                     0.0
# Enclosure_Type                  0.0
# Engine_Horsepower               0.0
# Hydraulics                      0.0
# Pushblock                       0.0
# Ripper                          0.0
# Scarifier                       0.0
# Tip_Control                     0.0
# Tire_Size                       0.0
# Coupler                         0.0
# Coupler_System                  0.0
# Grouser_Tracks                  0.0
# Hydraulics_Flow                 0.0
# Track_Type                      0.0
# Undercarriage_Pad_Width         0.0
# Stick_Length                    0.0
# Thumb                           0.0
# Pattern_Changer                 0.0
# Grouser_Type                    0.0
# Backhoe_Mounting                0.0
# Blade_Type                      0.0
# Travel_Controls                 0.0
# Differential_Type               0.0
# Steering_Controls               0.0
# YearOfSale                   1989.0

# %%
train_valid_copy.tail().T
# Out:
#                              409901     405777     411889     411890  \
# SalesID                   6286556.0  6256957.0  6312472.0  6312473.0
# SalePrice                   23000.0    11500.0    11000.0    11000.0
# MachineID                 1793587.0  1860454.0  1820676.0  1796787.0
# ModelID                      4605.0     6868.0    17231.0    17231.0
# datasource                    149.0      149.0      149.0      149.0
# auctioneerID                   99.0       99.0       99.0       99.0
# YearMade                     2006.0     1000.0     2006.0     2006.0
# MachineHoursCurrentMeter        0.0        0.0        0.0        0.0
# UsageBand                       0.0        0.0        0.0        0.0
# fiModelDesc                   500.0     1679.0      581.0      581.0
# fiBaseModel                   176.0      505.0      191.0      191.0
# fiSecondaryDesc                59.0        0.0        0.0        0.0
# fiModelSeries                   0.0        0.0        0.0        0.0
# fiModelDescriptor               0.0        0.0        0.0        0.0
# ProductSize                     0.0        3.0        5.0        5.0
# fiProductClassDesc              2.0       19.0        6.0        6.0
# state                           5.0        5.0        5.0        5.0
# ProductGroup                    1.0        4.0        4.0        4.0
# ProductGroupDesc                1.0        4.0        4.0        4.0
# Drive_System                    2.0        0.0        0.0        0.0
# Enclosure                       6.0        1.0        1.0        1.0
# Forks                           1.0        0.0        0.0        0.0
# Pad_Type                        2.0        0.0        0.0        0.0
# Ride_Control                    1.0        0.0        0.0        0.0
# Stick                           1.0        0.0        0.0        0.0
# Transmission                    8.0        0.0        0.0        0.0
# Turbocharged                    1.0        0.0        0.0        0.0
# Blade_Extension                 0.0        0.0        0.0        0.0
# Blade_Width                     0.0        0.0        0.0        0.0
# Enclosure_Type                  0.0        0.0        0.0        0.0
# Engine_Horsepower               0.0        0.0        0.0        0.0
# Hydraulics                      0.0       12.0        4.0        4.0
# Pushblock                       0.0        0.0        0.0        0.0
# Ripper                          0.0        0.0        0.0        0.0
# Scarifier                       0.0        0.0        0.0        0.0
# Tip_Control                     0.0        0.0        0.0        0.0
# Tire_Size                       0.0        0.0        0.0        0.0
# Coupler                         0.0        3.0        3.0        3.0
# Coupler_System                  0.0        0.0        0.0        0.0
# Grouser_Tracks                  0.0        0.0        0.0        0.0
# Hydraulics_Flow                 0.0        0.0        0.0        0.0
# Track_Type                      0.0        2.0        2.0        2.0
# Undercarriage_Pad_Width         0.0       19.0       19.0       19.0
# Stick_Length                    0.0       29.0       29.0       29.0
# Thumb                           0.0        2.0        3.0        3.0
# Pattern_Changer                 0.0        2.0        2.0        2.0
# Grouser_Type                    0.0        1.0        1.0        1.0
# Backhoe_Mounting                0.0        0.0        0.0        0.0
# Blade_Type                      0.0        0.0        0.0        0.0
# Travel_Controls                 0.0        0.0        0.0        0.0
# Differential_Type               0.0        0.0        0.0        0.0
# Steering_Controls               0.0        0.0        0.0        0.0
# YearOfSale                   2012.0     2012.0     2012.0     2012.0
#
#                              409203
# SalesID                   6283635.0
# SalePrice                   34000.0
# MachineID                 1869284.0
# ModelID                      4701.0
# datasource                    149.0
# auctioneerID                   99.0
# YearMade                     1000.0
# MachineHoursCurrentMeter        0.0
# UsageBand                       0.0
# fiModelDesc                   989.0
# fiBaseModel                   307.0
# fiSecondaryDesc                61.0
# fiModelSeries                   0.0
# fiModelDescriptor               0.0
# ProductSize                     0.0
# fiProductClassDesc             60.0
# state                           5.0
# ProductGroup                    6.0
# ProductGroupDesc                6.0
# Drive_System                    0.0
# Enclosure                       3.0
# Forks                           1.0
# Pad_Type                        0.0
# Ride_Control                    2.0
# Stick                           0.0
# Transmission                    0.0
# Turbocharged                    0.0
# Blade_Extension                 0.0
# Blade_Width                     0.0
# Enclosure_Type                  0.0
# Engine_Horsepower               0.0
# Hydraulics                      1.0
# Pushblock                       0.0
# Ripper                          0.0
# Scarifier                       0.0
# Tip_Control                     0.0
# Tire_Size                       9.0
# Coupler                         3.0
# Coupler_System                  0.0
# Grouser_Tracks                  0.0
# Hydraulics_Flow                 0.0
# Track_Type                      0.0
# Undercarriage_Pad_Width         0.0
# Stick_Length                    0.0
# Thumb                           0.0
# Pattern_Changer                 0.0
# Grouser_Type                    0.0
# Backhoe_Mounting                0.0
# Blade_Type                      0.0
# Travel_Controls                 0.0
# Differential_Type               4.0
# Steering_Controls               2.0
# YearOfSale                   2012.0

# %% [markdown]
# ### Now when all our values are numeric,we are able to fit them to a ML model.

# %%
TrainSet = train_valid_copy[train_valid_copy['YearOfSale'] != 2012]

# %%
ValidationSet = train_valid_copy[train_valid_copy['YearOfSale'] == 2012]

# %%
X_train = TrainSet.drop(['SalePrice'],axis=1)
y_train = TrainSet['SalePrice']
X_valid = ValidationSet.drop(['SalePrice'],axis=1)
y_valid = ValidationSet['SalePrice']

# %%
X_train
# Out:
#         SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 205615  1646770    1126363     8434         132          18.0      1974
# 233186  1728883    1523610     9105         132          99.0      1986
# 142491  1508502    1153157     4138         132          99.0      1972
# 115536  1452578    1544443     3854         132          99.0      1974
# 92301   1403418    1390168     7110         132          99.0      1986
# ...         ...        ...      ...         ...           ...       ...
# 397551  6286845    1818840     8050         149           2.0      2006
# 397589  6287076    1862704     4640         149           2.0      1000
# 397660  6287313    1805275     4666         149           2.0      2004
# 397995  6288403    1908296    26287         149           2.0      1000
# 397022  6285369    1811309     4666         149           2.0      2004
#
#         MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 205615                       0.0          0         4593         1744  ...
# 233186                       0.0          0         4772         1852  ...
# 142491                       0.0          0         2347          713  ...
# 115536                       0.0          0         1767          535  ...
# 92301                        0.0          0          744          245  ...
# ...                          ...        ...          ...          ...  ...
# 397551                       0.0          0          493          176  ...
# 397589                       0.0          0          732          242  ...
# 397660                       0.0          0          865          267  ...
# 397995                       0.0          0         1818          557  ...
# 397022                       0.0          0          865          267  ...
#
#         Stick_Length  Thumb  Pattern_Changer  Grouser_Type  Backhoe_Mounting  \
# 205615             0      0                0             0                 1
# 233186             0      0                0             0                 0
# 142491             0      0                0             0                 1
# 115536             0      0                0             0                 0
# 92301              0      0                0             0                 0
# ...              ...    ...              ...           ...               ...
# 397551             0      0                0             0                 0
# 397589             0      0                0             0                 0
# 397660             0      0                0             0                 1
# 397995             0      0                0             0                 0
# 397022             0      0                0             0                 1
#
#         Blade_Type  Travel_Controls  Differential_Type  Steering_Controls  \
# 205615           8                6                  0                  0
# 233186           0                0                  0                  0
# 142491           1                6                  0                  0
# 115536           0                0                  4                  2
# 92301            0                0                  0                  0
# ...            ...              ...                ...                ...
# 397551           0                0                  0                  0
# 397589           0                0                  0                  0
# 397660           6                6                  0                  0
# 397995           0                0                  0                  0
# 397022           6                6                  0                  0
#
#         YearOfSale
# 205615        1989
# 233186        1989
# 142491        1989
# 115536        1989
# 92301         1989
# ...            ...
# 397551        2011
# 397589        2011
# 397660        2011
# 397995        2011
# 397022        2011
#
# [401125 rows x 52 columns]

# %%
y_train
# Out:
# 205615     9500.0
# 233186    30000.0
# 142491    21000.0
# 115536    33000.0
# 92301     24000.0
#            ...
# 397551    34500.0
# 397589    19000.0
# 397660    24000.0
# 397995    18000.0
# 397022    24000.0
# Name: SalePrice, Length: 401125, dtype: float64

# %%
#Import Random Forest Regressor.
from sklearn.ensemble import RandomForestRegressor

# %%
#Instantiate and fit a model to a given data.


model = RandomForestRegressor(n_jobs=-1)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
y_pred =model.predict(X_valid)

# %%
#model.score(X_valid,y_valid)
# Out:
# 0.8739273829690865

# %%
#Our goal is to minimize the Root Mean Squared log Error...
#Import Mean Squared Log Error.
from sklearn.metrics import mean_squared_log_error

np.sqrt(mean_squared_log_error(y_valid,y_pred))
# Out:
# 0.24921126566184412

# %% [markdown]
# ##### The required score for Root Mean Squared Log Error:
# 0.24921126566184412
